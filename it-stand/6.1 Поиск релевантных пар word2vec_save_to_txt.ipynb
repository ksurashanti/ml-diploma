# %% [markdown]
# Есть датфрейм с authors, text, annotation и title. Текст предобработан, стоп-слова удалены. У одной статьи может быть несколько авторов, тогда они записаны в одной ячейке authors и разделены запятой.
#
# Функции:
# - для вычисления всех соавторов одного человека по ФИО, они могут быть записаны в разных ячейках датафрейма.
#
# - функция для векторизации текста.
#
# - функция для вычисления коэффициента схожести.
#
# - функция для рекомендации новых соавторов.
#
# В функцию для рекомендации новых соавторов подаётся на вход ФИО автора. На выходе ФИО автора, названия всех статей в которых он участвовал, список его соавторов, список трёх рекомендуемых новых авторов/коллективов авторов, названия их статей и коэффициент близости.
#
# Ограничения:
#
# - Нельзя рекомендовать автора самому себе
# - Нельзя рекомендовать автору его текущих соавторов.
#
# Особенности:
#
# Необходимо предусмотреть ситуацию когда рекомендуется несколько человек, написавших одну и ту же статью, при совпадении коэффициента близости у новых соавторов необходимо объединять их ФИО через запятую, писать их общую статью один раз и на 2 и 3 месте писать новых рекомендуемых авторов. При совпадении 2 и 3 рекомендации также следует их объединять и на третье место выводить следующих по коэффициенту схожести коллектив авторов/автора.

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict
import numpy as np
import pprint
from gensim.models import Word2Vec

# %%
df = pd.read_json('it-st-articles-full-PREPROC.json')
df
# Out:
#      year                                              title  \
# 0    2025  актуальный задача математический обеспечение с...
# 1    2025  обзор зарубежный международный опыт стандартиз...
# 2    2025  особенность перспектива применение структура п...
# 3    2025  подход одноклассовый классификация регулярный ...
# 4    2025  унификация описание программный аппаратный мод...
# ..    ...                                                ...
# 335  2015  проблема разработка применение российский феде...
# 336  2015  опыт интеграция проблема стандартизация распре...
# 337  2014  путь обеспечение безопасность функционирование...
# 338  2014  развитие медицинский информатика новый направл...
# 339  2014  комплекс обеспечение экологический безопасност...
#
#                                                authors  \
# 0          Головин С.А., Лоцманов А.Н., Тихомиров С.Г.
# 1                                        Денисова О.А.
# 2    Быковцев Ю.А., Лохин В.М., Манько С.В., Смирно...
# 3                                         Демидов Н.А.
# 4      Кряхтунов Г.М., Боронников А.С., Платонова О.В.
# ..                                                 ...
# 335                                       Щербина В.И.
# 336                                     Куделькин В.А.
# 337  Петров А.Б.; Андрианова Е.Г.; Сычева А.И.; Баг...
# 338   Борисова Н.В.; Карачунский А.И.; Старичкова Ю.В.
# 339  Бурмака А.А.; Червяков Л.И.; Георгиев М.Д.; Ко...
#
#                                                   link  \
# 0    http://itstd-journal.ru/wp-content/uploads/202...
# 1    http://itstd-journal.ru/wp-content/uploads/202...
# 2    http://itstd-journal.ru/wp-content/uploads/202...
# 3    http://itstd-journal.ru/wp-content/uploads/202...
# 4    http://itstd-journal.ru/wp-content/uploads/202...
# ..                                                 ...
# 335  http://itstd-journal.ru/wp-content/uploads/201...
# 336  http://itstd-journal.ru/wp-content/uploads/201...
# 337  http://itstd-journal.ru/wp-content/uploads/201...
# 338  http://itstd-journal.ru/wp-content/uploads/201...
# 339  http://itstd-journal.ru/wp-content/uploads/201...
#
#                                             annotation  \
# 0    российский союз промышленник предприниматель р...
# 1    мир меняться невероятный темп наблюдать прорыв...
# 2    модульный подход построение манипуляционный ро...
# 3    резюме цель статья рассмотреть задача выявлени...
# 4    проектирование базис сверхбольшой интегральный...
# ..                                                 ...
# 335
# 336  рассматриваться опыт разработка интегрировать ...
# 337
# 338
# 339
#
#                                                   text
# 0    : ИТ стандартизация, умный (SMART) стандарт, э...
# 1    : цифровая трансформация, SMART-стандарты, CEN...
# 2    : модульный манипуляционный робот, динамическа...
# 3    : регулярное выражение, паттерн новизны, BERT,...
# 4    : описание, программные модели, аппаратные мод...
# ..                                                 ...
# 335  : переводные стандарты, международные стандарт...
# 336  : мониторинг, распределенные системы, интеграц...
# 337  : безопасность функционирования, информационны...
# 338  : медицинская информатика, здравоохранение, ин...
# 339  : анализ, безопасность, газораспределение, ком...
#
# [340 rows x 6 columns]

# %%
#df['authors'] = df['authors'].str.split(',') #авторов через запятую разделяем

# %%
import re

def find_coauthors(df, author):
    coauthors = set()
    # Паттерн для разделения по пробелу после точки, перед заглавной буквой
    split_pattern = re.compile(r'(?<=\.)\s+(?=[А-ЯЁ])')
    
    for authors_str in df['authors'].dropna():
        # Нормализуем разделители: заменяем ; и , на специальный символ |
        normalized = re.sub(r'[;,]', '|', authors_str)
        # Разбиваем по | и удаляем пустые строки
        parts = [p.strip() for p in normalized.split('|') if p.strip()]
        
        authors_list = []
        for part in parts:
            # Делим часть на авторов по паттерну
            split_part = split_pattern.split(part)
            authors_list.extend([a.strip() for a in split_part if a.strip()])
        
        # Проверяем наличие автора и собираем соавторов
        if author in authors_list:
            for coauthor in authors_list:
                if coauthor != author:
                    coauthors.add(coauthor)
    
    return sorted(coauthors)

print(find_coauthors(df, 'Андрианова Е.Г.'))

def calculate_similarity(tfidf_matrix, target_indices, all_indices):
    similarities = cosine_similarity(tfidf_matrix[target_indices], tfidf_matrix[all_indices])
    return similarities.max(axis=0)
# Out:
# ['Багров С.В.', 'Буланова Ю.В.', 'Головин О.Л.', 'Головин С.А.', 'Демидов Н.А.', 'Коняев Г.Б.', 'Морнев А.А.', 'Назаров А.Н.', 'Петров А.Б.', 'Пискунова Д.В.', 'Поликашечкин Д.А.', 'Полторак А.В.', 'Руденская Ю.С.', 'Сычева А.И.', 'Трохаченкова Н.Н.', 'Чукалина Е.Р.', 'Шумилов В.Н.', 'Юдаев И.А.']

# %%
#модель Word2Vec, запускай только в том случае если нужно обучить
def train_word2vec_model(texts, save_path='word2vec.model'):
    sentences = [text.split() for text in texts]
    model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)
    model.save(save_path)  # Сохраняем модель на диск
    return model

texts = df['texts'].tolist()  # Тексты для обучения
train_word2vec_model(texts, save_path='word2vec.model')

# %%
def load_word2vec_model(load_path='word2vec.model'):
    return Word2Vec.load(load_path)  # Загружаем модель с диска

# %%
def vectorize_text_with_word2vec(text, model):
    words = text.split()
    word_vectors = [model.wv[word] for word in words if word in model.wv]
    if len(word_vectors) > 0:
        return np.mean(word_vectors, axis=0)  #усреднение векторов
    else:
        return np.zeros(model.vector_size)  #нулевой вектор если слов нет

def vectorize_texts_with_word2vec(df, text_column='text', model_path='word2vec.model'):
    print("Загрузка модели Word2Vec...")
    word2vec_model = load_word2vec_model(model_path)
    
    print("Векторизация текстов...")
    vectors = df[text_column].apply(lambda x: vectorize_text_with_word2vec(x, word2vec_model))
    
    #список векторов в массив
    return np.array(vectors.tolist()), word2vec_model

# %%
def recommend_new_coauthors(df, author_name, model_path='word2vec.model'):
    target_mask = df['authors'].str.contains(author_name, regex=False)  #данные автора
    target_indices = df[target_mask].index.tolist()
    
    if not target_indices:
        return {"error": "Автор не найден"}
    
    current_coauthors = find_coauthors(df, author_name)  #текущие соавторы
    
    tfidf_matrix, _ = vectorize_texts_with_word2vec(df, text_column='text', model_path=model_path)
    
    all_indices = df.index.tolist()
    similarities = calculate_similarity(tfidf_matrix, target_indices, all_indices)  # Схожести

    results = pd.DataFrame({
        'index': all_indices,
        'similarity': similarities,
        'authors': df['authors'],
        'title': df['title']
    })
    
    results = results[
        (results['similarity'] < 1.0) &  #исключаем статьи автора
        (~results['authors'].isin([author_name]))  #исключаем соавторов
    ]
    
    #группировка по коэффициенту схожести
    grouped = results.groupby('similarity').agg({
        'authors': lambda x: ', '.join(sorted(set(', '.join(x).split(', ')))),
        'title': lambda x: ', '.join(sorted(set(x)))
    }).reset_index().sort_values('similarity', ascending=False)
    
    recommendations = []
    used_authors = set(current_coauthors + [author_name])  #формируем рекомендации
    
    for _, row in grouped.iterrows():
        candidates = [a.strip() for a in row['authors'].split(',') if a.strip() not in used_authors]
        if candidates:
            unique_candidates = []
            for candidate in candidates:
                if candidate not in used_authors:
                    unique_candidates.append(candidate)
                    used_authors.add(candidate)
            
            if unique_candidates:
                recommendations.append({
                    'authors': ', '.join(unique_candidates),
                    'titles': row['title'],
                    'similarity': round(row['similarity'], 2)
                })
        
        if len(recommendations) >= 3:
            break
    
    output = {
        "Автор": author_name,
        "Текущие соавторы": current_coauthors,
        "Статьи": df[target_mask]['title'].tolist(),
        "Рекомендуемые соавторы": recommendations[:3]
    }
    
    #результаты в файлы
    save_results_to_txt(author_name, current_coauthors, output["Статьи"], output["Рекомендуемые соавторы"], df)
    
    return output

# %%
def save_results_to_txt(author_name, current_coauthors, articles, recommendations, df):
    #создаем папку
    import os
    if not os.path.exists("output"):
        os.makedirs("output")

    #файл 1: информация об авторе, его соавторах и нулевой статье
    with open(f"output/{author_name}_info.txt", "w", encoding="utf-8") as f:
        f.write(f"Автор: {author_name}\n")
        f.write(f"Соавторы: {', '.join(current_coauthors)}\n\n")
        
        #статьи у автора
        if articles:
            try:
                first_article = df[df['title'] == articles[0]].iloc[0]
                f.write(f"Заголовок: {first_article['title']}\n")
                f.write(f"Аннотация: {first_article['annotation']}\n")
                f.write(f"Текст: {first_article['text']}\n")
            except IndexError:
                f.write("Нулевая статья не найдена.\n")
        else:
            f.write("Статьи автора не найдены.\n")

    #файлы 2-4: рекомендуемые статьи
    for i, rec in enumerate(recommendations[:3], start=1):
        with open(f"output/{author_name}_recommendation_{i}.txt", "w", encoding="utf-8") as f:
            f.write(f"Коэффициент схожести: {rec['similarity']}\n")
            f.write(f"Рекомендуемые авторы: {rec['authors']}\n\n")
            
            titles = rec['titles'].split(', ')
            for title in titles:
                try:
                    article = df[df['title'] == title].iloc[0]
                    f.write(f"Заголовок: {article['title']}\n")
                    f.write(f"Аннотация: {article['annotation']}\n")
                    f.write(f"Текст: {article['text']}\n\n")
                except IndexError:
                    f.write(f"Статья с заголовком '{title}' не найдена.\n\n")

# %%
import pprint

rec_list = recommend_new_coauthors(df, 'Андрианова Е.Г.', model_path='word2vec.model')
pprint.pprint(rec_list)
print('\n Статьи сохранены в папку output')
# Out:
# Загрузка модели Word2Vec...
# Векторизация текстов...
# {'Автор': 'Андрианова Е.Г.',
#  'Рекомендуемые соавторы': [{'authors': 'Асирян А.В., Григорьев Л.И.',
#                              'similarity': 1.0,
#                              'titles': 'особенность современный этап развитие '
#                                        'автоматизированный система '
#                                        'диспетчерский управление объект '
#                                        'нефтегазовый производство'},
#                             {'authors': 'Папилина Т.М., Соанху Х.В.',
#                              'similarity': 1.0,
#                              'titles': 'системный анализ проект электронный '
#                                        'правительство республика кот далее '
#                                        'ивуар'},
#                             {'authors': 'Лукьянчиков О. И.; Никуличев Е.В.; '
#                                         'Филатов В. В.',
#                              'similarity': 1.0,
#                              'titles': 'технология агентный реляционный '
#                                        'отображение агентный ориентировать '
#                                        'программирование'}],
#  'Статьи': ['решение задача распознавание интерпретация изображение объект '
#             'основа гарнитур смешанный реальность',
#             'хакерский кибератака реальный область',
#             'цифровой трансформация корпоративный образовательный процесс',
#             'сравнение метод прогнозирование финансовый временной ряд',
#             'методика проведение ит аудит основа риск ориентировать подход',
#             'принцип подход проектирование архитектура система',
#             'направление совершенствование аудит информационный система',
#             'программа перенос данные таблица программа обработка',
#             'концептуальный аспект построение доверенный неоднородный блокчейн '
#             'среда новый технологический уклад',
#             'опыт внедрение стандарт информационный подсистема сервисный '
#             'департамент производственный ит компания',
#             'роль стандарт подготовка востребовать ит кадр предприятие '
#             'оборонный промышленный комплекс',
#             'вопрос развитие стандартизация технология интернет вещь объект '
#             'россия участие российский компания',
#             'принцип построение ситуационный центр цифровой кафедра',
#             'процесс модернизация система управление персонал основа расширить '
#             'метаописание профиль должность',
#             'путь обеспечение безопасность функционирование распределённый '
#             'информационный система государственный муниципальный управление'],
#  'Текущие соавторы': ['Багров С.В.',
#                       'Буланова Ю.В.',
#                       'Головин О.Л.',
#                       'Головин С.А.',
#                       'Демидов Н.А.',
#                       'Коняев Г.Б.',
#                       'Морнев А.А.',
#                       'Назаров А.Н.',
#                       'Петров А.Б.',
#                       'Пискунова Д.В.',
#                       'Поликашечкин Д.А.',
#                       'Полторак А.В.',
#                       'Руденская Ю.С.',
#                       'Сычева А.И.',
#                       'Трохаченкова Н.Н.',
#                       'Чукалина Е.Р.',
#                       'Шумилов В.Н.',
#                       'Юдаев И.А.']}
#
#  Статьи сохранены в папку output
